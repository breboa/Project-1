# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %% [markdown]
# STEP 1: SET UP ENVIRONMENT & GET DATA

# %%
# import packages
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
#import data into pd dataframe 
kc_data = pd.read_csv('kc_house_data.csv')

# %% [markdown]
# STEP 2: INSPECT DATA

# %%
kc_data.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0         NaN   0.0     ...          7        1180
# 1      7242     2.0         0.0   0.0     ...          7        2170
# 2     10000     1.0         0.0   0.0     ...          6         770
# 3      5000     1.0         0.0   0.0     ...          7        1050
# 4      8080     1.0         0.0   0.0     ...          8        1680
#
#    sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
kc_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
# id               21597 non-null int64
# date             21597 non-null object
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       19221 non-null float64
# view             21534 non-null float64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null object
# yr_built         21597 non-null int64
# yr_renovated     17755 non-null float64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# ...

# %% [markdown]
# Upon inspecting our data, we noticed that there are 3 columns with NULL values: waterfront, view, and yr_renovated.

# %%
#Check to see if any duplicate ids 
kc_data.duplicated(subset=['id']).any()
# Out:
# True

# %%
#Identify the duplicated values to determine which one to remove from dataset 
pd.concat(g for _, g in kc_data.groupby('id') if len(g) > 1)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 2494      1000102   9/16/2014   280000.0         6       3.00         2400
# 2495      1000102   4/22/2015   300000.0         6       3.00         2400
# 16800     7200179  10/16/2014   150000.0         2       1.00          840
# 16801     7200179   4/24/2015   175000.0         2       1.00          840
# 11421   109200390   8/20/2014   245000.0         3       1.75         1480
# 11422   109200390  10/20/2014   250000.0         3       1.75         1480
# 12405   123039336   6/11/2014   148000.0         1       1.00          620
# 12406   123039336   12/8/2014   244900.0         1       1.00          620
# 7785    251300110   7/31/2014   225000.0         3       2.25         2510
# 7786    251300110   1/14/2015   358000.0         3       2.25         2510
# 9225    302000375   8/14/2014   169100.0         3       2.00         1050
# ...

# %% [markdown]
# We decided to keep the id in repeated ids that has the later sell date b/c its price would be more relevant to current market conditions and the attributes of the house are the same (except for waterfront on occasion because we sub-ed in null values ) for both times.

# %%
#Remove duplicates; keep the last duplicated as more relevant 
kc_data.drop_duplicates(subset='id', keep='last', inplace=True)

# %%
#Check to ensure duplicated data has been removed
kc_data.duplicated(subset=['id']).any()
# Out:
# False

# %%
kc_data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.142000e+04  2.142000e+04  21420.000000  21420.000000  21420.000000
# mean   4.580940e+09  5.418614e+05      3.373950      2.118429   2083.132633
# std    2.876761e+09  3.675569e+05      0.925405      0.768720    918.808412
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123537e+09  3.249500e+05      3.000000      1.750000   1430.000000
# 50%    3.904921e+09  4.505500e+05      3.000000      2.250000   1920.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.142000e+04  21420.000000  19067.000000  21357.000000  21420.000000
# mean   1.512804e+04      1.495985      0.007657      0.234677      3.410784
# ...

# %% [markdown]
# Next, we will deal with categorical variables. Based on the mean and range shown in the tables, we realized that grade and condition of home are categorical variables. We are going to change them to dummy variables

# %%
#Checking for range of values in categorical variables 
kc_data['condition'].unique()

# %%
kc_data['grade'].unique()

# %%
# create new columns of dummy variable; drop first value so we have n-1 values 
condition_dummies = pd.get_dummies(kc_data['condition'],prefix = 'condition', drop_first=True)
grade_dummies = pd.get_dummies(kc_data['grade'],prefix = 'grade', drop_first=True)

# %%
condition_dummies.head(3)
# Out:
#    condition_2  condition_3  condition_4  condition_5
# 0            0            1            0            0
# 1            0            1            0            0
# 2            0            1            0            0

# %%
#Check on distribution of grade 
grade_dummies.sum()
# Out:
# grade_4       27
# grade_5      234
# grade_6     1995
# grade_7     8889
# grade_8     6041
# grade_9     2606
# grade_10    1130
# grade_11     396
# grade_12      88
# grade_13      13
# dtype: int64

# %%
#Visualize categorical variables usingbox plot; identify outliers 
kc_data.boxplot('price',by = 'condition',figsize = (8,8))

# %%
kc_data.boxplot('price',by = 'grade',figsize = (8,8))

# %%
#Look at distribution of column using groupby describe 
kc_data.groupby('condition').price.describe()
# Out:
#              count           mean            std       min       25%  \
# condition
# 1             28.0  349480.357143  274653.006112   78000.0  194500.0
# 2            162.0  334005.487654  251024.562178   80000.0  191000.0
# 3          13900.0  543939.561223  365114.548430   83000.0  330000.0
# 4           5643.0  522310.528974  358422.636321   89000.0  305000.0
# 5           1687.0  613289.410788  411113.934798  110000.0  350000.0
#
#                 50%       75%        max
# condition
# 1          282500.0  434625.0  1500000.0
# 2          280000.0  403750.0  2560000.0
# 3          452725.0  642112.5  7060000.0
# 4          440000.0  626000.0  7700000.0
# 5          529950.0  725000.0  3650000.0

# %%
kc_dummies = pd.concat([kc_data, condition_dummies, grade_dummy], axis = 1)
kc_dummies.drop(['condition','grade'],axis=1, inplace=True);

# %% [markdown]
# Use temporary regression to see impact of transformed categorical variable on R2

# %%
temp_reg_condition = ols(formula = 'price~condition_dummies',data=kc_dummies).fit()
temp_reg_condition.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     35.12
# Date:                Thu, 20 Jun 2019   Prob (F-statistic):           2.77e-29
# Time:                        09:41:00   Log-Likelihood:            -3.0481e+05
# No. Observations:               21420   AIC:                         6.096e+05
# Df Residuals:                   21415   BIC:                         6.097e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %% [markdown]
# STEP 4: CLEAN DATA

# %%
#Replace NaN values in waterfront column with mean value 
mean_waterfront = kc_dummies.waterfront.mean()
kc_dummies['waterfront'].fillna(0, inplace=True)

#Replace NAN values in view column with mean value 
mean_view = kc_dummies.view.mean()
kc_dummies['view'].fillna(mean_view, inplace=True)

#Replace NAN values in yr_renovated column with 0 as opposted to mean value as mean of year renovated 
#in NAN set would not be representative of the data
kc_dummies['yr_renovated'].fillna(0, inplace=True)

kc_dummies.isna().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# condition_2      0
# condition_3      0
# condition_4      0
# condition_5      0
# grade_4          0
# grade_5          0
# grade_6          0
# grade_7          0
# grade_8          0
# grade_9          0
# grade_10         0
# grade_11         0
# grade_12         0
# grade_13         0
# dtype: int64

# %%
#Drop id column so that is it not used as a variable in the regression 
kc_data.drop(['id'],axis=1, inplace=True);

# %% [markdown]
# STEP 5: VISUALIZE DATA & CHECK ASSUMPTIONS

# %%
#Use histogram to check normality of all variables 
kc_data.hist(figsize=(18,10))
plt.show()

# %%
#Use scatterplot to check linearity
for column in ['bathrooms', 'condition', 'sqft_above', 'zipcode', 'lat']:
    plt.scatter(kc_data[column], kc_data.price, label=column)
    plt.legend()
    plt.show()

# %%
for column in ['waterfront', 'yr_built', 'sqft_living']:
    plt.scatter(kc_dummies[column], kc_dummies.price, label=column)
    plt.legend()
    plt.show()

# %%
kc_predictors = kc_data[['bathrooms', 'sqft_living', 'lat', 'price', "yr_built", "condition"]].copy()
kc_predictors.head()
# Out:
#    bathrooms  sqft_living      lat     price  yr_built  condition
# 0       1.00         1180  47.5112  221900.0      1955          3
# 1       2.25         2570  47.7210  538000.0      1951          3
# 2       1.00          770  47.7379  180000.0      1933          3
# 3       3.00         1960  47.5208  604000.0      1965          5
# 4       2.00         1680  47.6168  510000.0      1987          3

# %% [markdown]
# STEP 5: CHECK MULTICOLINEARITY

# %%
corr = kc_data.corr()
corr
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.018450  0.000691   0.004343    -0.013451 -0.132648
# price         -0.018450  1.000000  0.309640   0.525215     0.701295  0.088789
# bedrooms       0.000691  0.309640  1.000000   0.515383     0.579069  0.032490
# bathrooms      0.004343  0.525215  0.515383   1.000000     0.755522  0.087779
# sqft_living   -0.013451  0.701295  0.579069   0.755522     1.000000  0.172586
# sqft_lot      -0.132648  0.088789  0.032490   0.087779     0.172586  1.000000
# floors         0.018139  0.254972  0.177734   0.501803     0.352868 -0.005561
# waterfront    -0.003971  0.264741 -0.002351   0.063532     0.104603  0.021479
# view           0.010909  0.393038  0.078417   0.185018     0.281041  0.075435
# condition     -0.024300  0.034219  0.025893  -0.129362    -0.061677 -0.009169
# grade          0.006470  0.666835  0.357988   0.665587     0.762477  0.113656
# ...

# %%
corr[abs(kc_data.corr() > 0.75)]
# Out:
#                 id  price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# id             1.0    NaN       NaN        NaN          NaN       NaN     NaN
# price          NaN    1.0       NaN        NaN          NaN       NaN     NaN
# bedrooms       NaN    NaN       1.0        NaN          NaN       NaN     NaN
# bathrooms      NaN    NaN       NaN   1.000000     0.755522       NaN     NaN
# sqft_living    NaN    NaN       NaN   0.755522     1.000000       NaN     NaN
# sqft_lot       NaN    NaN       NaN        NaN          NaN       1.0     NaN
# floors         NaN    NaN       NaN        NaN          NaN       NaN     1.0
# waterfront     NaN    NaN       NaN        NaN          NaN       NaN     NaN
# view           NaN    NaN       NaN        NaN          NaN       NaN     NaN
# condition      NaN    NaN       NaN        NaN          NaN       NaN     NaN
# grade          NaN    NaN       NaN        NaN     0.762477       NaN     NaN
# ...

# %%
sns.heatmap(corr,cmap = 'BuPu')

# %% [markdown]
# Based on multicolinearity assumption, we will not use both sqft_above and sqft_living in our regression model.

# %%
# import statsmodels.api as sm
# import statsmodels.formula.api as smf
# import scipy.stats as stats
# import statsmodels.stats.api as sms


# results = [['ind_var', 'r_squared', 'intercept', 'slope', 'p-value', 'normality (JB)' ]]
# for idx, val in enumerate(['bathrooms', 'sqft_above', 'sqft_living']):
#     print ("Boston Housing DataSet - Regression Analysis and Diagnostics for formula: price~" + val)
#     print ("-------------------------------------------------------------------------------------")


#     f = 'price~' + val
 
#     model = smf.ols(formula=f, data=data).fit()
    
#     X_new = pd.DataFrame({val: [data[val].min(), data[val].max()]});
#     preds = model.predict(X_new)
#     data.plot(kind='scatter', x=val, y='medv');
#     plt.plot(X_new, preds, c='red', linewidth=2);
#     plt.show()
#     fig = plt.figure(figsize=(15,8))
#     fig = sm.graphics.plot_regress_exog(model, val, fig=fig)
#     fig = sm.graphics.qqplot(model.resid, dist=stats.norm, line='45', fit=True,   )
#     plt.show()
    
#     results.append([val, model.rsquared, model.params[0], model.params[1], model.pvalues[1], sms.jarque_bera(model.resid)[0] ])
#     input("Press Enter to continue...")

# %%
regression_kc = ols(formula= "price~bathrooms+sqft_living+lat+yr_built+condition", data=kc_predictors).fit()
regression_kc.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.589
# Model:                            OLS   Adj. R-squared:                  0.589
# Method:                 Least Squares   F-statistic:                     6129.
# Date:                Wed, 19 Jun 2019   Prob (F-statistic):               0.00
# Time:                        15:42:00   Log-Likelihood:            -2.9537e+05
# No. Observations:               21420   AIC:                         5.907e+05
# Df Residuals:                   21414   BIC:                         5.908e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept   -2.723e+07   6.08e+05    -44.794      0.000   -2.84e+07    -2.6e+07
# ...
